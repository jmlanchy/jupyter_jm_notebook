# %%
from Bio import SeqIO
from Bio import motifs
from Bio.Seq import Seq

# possible motifs to search for:
# RNA33, 5-GUAGUGUGUG;RNA34, 5-GUCUGUUGUGUG in Heil et al. 2004, Science 303 (5663):1526-1529.
# GUGUGU, GUGUGUG, GUUGUGU, GUUGUGUG in Forsbach et al. 2008, J Immunol 180:3729-3738.

GUmotif = (Seq("GTGTG"),Seq("GTTGTG"),Seq("GTGTGTG"),Seq("GTTGTGTG"))
for mot in GUmotif:
    for seq_record in SeqIO.parse("sequence.gb", "genbank"):
        instances = [mot]
        m = motifs.create(instances)
        total = 0
        print("List of " + str(mot.transcribe()) + " " + "motifs in " + seq_record.annotations["source"] + " genome.\n")
        for pos,seq in m.instances.search(seq_record.seq):
            total = total + 1
            #print("%i : %s" %(pos,seq.transcribe()))
        
            #I will save the coordinates of the GU motifs in a CSV file
        
        print("\tThere are a total of " + str(total) + " " + str(mot.transcribe()) + " motifs in the " + seq_record.annotations["source"] + " genome.")
        print("\tThe " + seq_record.annotations["source"] + " genome is " + str(len(seq_record)) + " nucleotides-long.\n")
# Out:
# List of GUGUG motifs in Human immunodeficiency virus 1 (HIV-1) genome.
#
# 	There are a total of 10 GUGUG motifs in the Human immunodeficiency virus 1 (HIV-1) genome.
# 	The Human immunodeficiency virus 1 (HIV-1) genome is 9181 nucleotides-long.
#
# List of GUGUG motifs in Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome.
#
# 	There are a total of 58 GUGUG motifs in the Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome.
# 	The Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome is 30119 nucleotides-long.
#
# List of GUGUG motifs in SARS coronavirus Tor2 genome.
#
# 	There are a total of 37 GUGUG motifs in the SARS coronavirus Tor2 genome.
# 	The SARS coronavirus Tor2 genome is 29751 nucleotides-long.
#
# List of GUGUG motifs in Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome.
#
# 	There are a total of 35 GUGUG motifs in the Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome.
# 	The Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome is 29903 nucleotides-long.
#
# List of GUUGUG motifs in Human immunodeficiency virus 1 (HIV-1) genome.
#
# 	There are a total of 2 GUUGUG motifs in the Human immunodeficiency virus 1 (HIV-1) genome.
# 	The Human immunodeficiency virus 1 (HIV-1) genome is 9181 nucleotides-long.
#
# List of GUUGUG motifs in Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome.
#
# 	There are a total of 16 GUUGUG motifs in the Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome.
# 	The Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome is 30119 nucleotides-long.
#
# List of GUUGUG motifs in SARS coronavirus Tor2 genome.
#
# 	There are a total of 13 GUUGUG motifs in the SARS coronavirus Tor2 genome.
# 	The SARS coronavirus Tor2 genome is 29751 nucleotides-long.
#
# List of GUUGUG motifs in Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome.
#
# 	There are a total of 11 GUUGUG motifs in the Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome.
# 	The Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome is 29903 nucleotides-long.
#
# List of GUGUGUG motifs in Human immunodeficiency virus 1 (HIV-1) genome.
#
# 	There are a total of 1 GUGUGUG motifs in the Human immunodeficiency virus 1 (HIV-1) genome.
# 	The Human immunodeficiency virus 1 (HIV-1) genome is 9181 nucleotides-long.
#
# List of GUGUGUG motifs in Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome.
#
# 	There are a total of 1 GUGUGUG motifs in the Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome.
# 	The Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome is 30119 nucleotides-long.
#
# List of GUGUGUG motifs in SARS coronavirus Tor2 genome.
#
# 	There are a total of 5 GUGUGUG motifs in the SARS coronavirus Tor2 genome.
# 	The SARS coronavirus Tor2 genome is 29751 nucleotides-long.
#
# List of GUGUGUG motifs in Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome.
#
# 	There are a total of 2 GUGUGUG motifs in the Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome.
# 	The Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome is 29903 nucleotides-long.
#
# List of GUUGUGUG motifs in Human immunodeficiency virus 1 (HIV-1) genome.
#
# 	There are a total of 2 GUUGUGUG motifs in the Human immunodeficiency virus 1 (HIV-1) genome.
# 	The Human immunodeficiency virus 1 (HIV-1) genome is 9181 nucleotides-long.
#
# List of GUUGUGUG motifs in Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome.
#
# 	There are a total of 2 GUUGUGUG motifs in the Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome.
# 	The Middle East respiratory syndrome-related coronavirus (MERS-CoV) genome is 30119 nucleotides-long.
#
# List of GUUGUGUG motifs in SARS coronavirus Tor2 genome.
#
# 	There are a total of 1 GUUGUGUG motifs in the SARS coronavirus Tor2 genome.
# 	The SARS coronavirus Tor2 genome is 29751 nucleotides-long.
#
# List of GUUGUGUG motifs in Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome.
#
# 	There are a total of 1 GUUGUGUG motifs in the Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome.
# 	The Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) genome is 29903 nucleotides-long.
