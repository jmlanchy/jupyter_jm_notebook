# %%
from Bio import SeqIO
from Bio import motifs
from Bio.Seq import Seq 
# RNA33, 5-GUAGUGUGUG;RNA34, 5-GUCUGUUGUGUG from Heil et al. Science 2004
# GUUGUGU
instances = [Seq("GT")]
m = motifs.create(instances)
total=0
for pos, seq in m.instances.search(partial_covid19):
    total = total + 1
#print("%i : %s" % (pos, seq)) 
print("There are a total of "+str(total)+" GU motifs in the covid19 sequence.")

instances = [Seq("GTT")]
m = motifs.create(instances)
covid19 = Seq("...")
total=0
for pos, seq in m.instances.search(partial_covid19):
    total = total + 1
#print("%i : %s" % (pos, seq)) 
print("There are a total of "+str(total)+" GUU motifs in the covid19 sequence.")

instances = [Seq("GTGT")]
m = motifs.create(instances)
total=0
for pos, seq in m.instances.search(partial_covid19):
    total = total + 1
#print("%i : %s" % (pos, seq)) 
print("There are a total of "+str(total)+" GUGU motifs in the covid19 sequence.")

instances = [Seq("GTTGT")]
m = motifs.create(instances)
total=0
for pos, seq in m.instances.search(partial_covid19):
    total = total + 1
#print("%i : %s" % (pos, seq)) 
print("There are a total of "+str(total)+" GUUGU motifs in the covid19 sequence.")

instances = [Seq("GTGTG")]
m = motifs.create(instances)
total=0
for pos, seq in m.instances.search(partial_covid19):
    total = total + 1
#print("%i : %s" % (pos, seq)) 
print("There are a total of "+str(total)+" GUGUG motifs in the covid19 sequence.")

instances = [Seq("GTTGTGTG")]
m = motifs.create(instances)
total=0
for pos, seq in m.instances.search(partial_covid19):
    total = total + 1
#print("%i : %s" % (pos, seq)) 
print("There are a total of "+str(total)+" GUUGUGUG motifs in the covid19 sequence.")

instances = [Seq("GTGTGTG")]
m = motifs.create(instances)
total=0
for pos, seq in m.instances.search(covid19):
    total = total + 1
#print("%i : %s" % (pos, seq)) 
print("There are a total of "+str(total)+" GUGUGUG motifs in the covid19 sequence.")
# Out:
# There are a total of 1990 GU motifs in the covid19 sequence.
# There are a total of 700 GUU motifs in the covid19 sequence.
# There are a total of 190 GUGU motifs in the covid19 sequence.
# There are a total of 69 GUUGU motifs in the covid19 sequence.
# There are a total of 35 GUGUG motifs in the covid19 sequence.
# There are a total of 1 GUUGUGUG motifs in the covid19 sequence.
# There are a total of 2 GUGUGUG motifs in the covid19 sequence.
