# %%
from Bio import SeqIO
from Bio import motifs
from Bio.Seq import Seq
from Bio.Alphabet import IUPAC 

instances = [Seq("GT")]
m = motifs.create(instances)
partial_covid19 = Seq("...",m.alphabet)
total=0
for pos, seq in m.instances.search(partial_covid19):
    total = total + (len(seq)/2)
    print("%i : %s" % (pos, seq)) 
#print("There are a total of "+str(total)+" GT motifs in the partial_covid19 sequence.")
